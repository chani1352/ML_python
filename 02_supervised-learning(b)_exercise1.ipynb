# %% [markdown]
# # 결정트리

# %% [markdown]
# ## 공통

# %%
# %config InlineBackend.figure_format = "retina"
# %config InlineBackend.figure_formats = ["pdf", "svg"]

# %%
import pandas as pd
import numpy as np
import mglearn
import matplotlib
import matplotlib.pyplot as plt
from cycler import cycler

#matplotlib.rc("font", family="Malgun Gothic")
matplotlib.rc("font", family="AppleGothic")
# matplotlib.rc('font', family='NanumBarunGothic')
matplotlib.rcParams["axes.unicode_minus"] = False

plt.rcParams["savefig.dpi"] = 300
plt.rcParams["figure.dpi"] = 300
plt.rcParams["image.cmap"] = "viridis"
plt.rcParams["image.interpolation"] = "none"
plt.rcParams["savefig.bbox"] = "tight"
plt.rcParams["lines.linewidth"] = 2
plt.rcParams["legend.numpoints"] = 1
plt.rc(
    "axes",
    prop_cycle=(
        cycler("color", mglearn.plot_helpers.cm_cycle.colors)
        + cycler("linestyle", ["-", "-", "--", (0, (3, 3)), (0, (1.5, 1.5))])
    ),
)

np.set_printoptions(precision=3, suppress=True)
pd.set_option("display.max_columns", 8)
pd.set_option("display.precision", 2)

# %% [markdown]
# ## 연습문제 01

# %% [markdown]
# ### 연습문제01. load_iris 데이터를 로드하고, 데이터를 탐색하세요.
# - 데이터셋의 특성과 타깃(target)의 개수를 확인하세요.
# - 각 특성의 기초 통계 정보를 출력하세요.

# %%
from sklearn.datasets import load_iris
data = load_iris()
print(f"data의 개수 : {data.data.shape}")
print(f"data 타깃의 개수 : {data.target.shape}")
df = pd.DataFrame(data.data, columns=data.feature_names)
print(df.describe())
# Out:
# data의 개수 : (150, 4)
# data 타깃의 개수 : (150,)
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count             150.00            150.00             150.00
# mean                5.84              3.06               3.76
# std                 0.83              0.44               1.77
# min                 4.30              2.00               1.00
# 25%                 5.10              2.80               1.60
# 50%                 5.80              3.00               4.35
# 75%                 6.40              3.30               5.10
# max                 7.90              4.40               6.90
#
#        petal width (cm)
# count            150.00
# mean               1.20
# std                0.76
# min                0.10
# 25%                0.30
# 50%                1.30
# 75%                1.80
# max                2.50

# %% [markdown]
# ### 연습문제01-2. 데이터를 학습 데이터와 테스트 데이터로 나누세요.
# - 학습 데이터와 테스트 데이터의 크기를 출력하세요.
#     - 데이터 분할은 train_test_split 함수를 사용하세요.
#     - 학습 데이터와 테스트 데이터의 비율은 80:20으로 설정하세요.

# %%
from sklearn.model_selection  import train_test_split
X_train,X_test,y_train,y_test = train_test_split(data.data,data.target,test_size=0.2,random_state=42)
print(f"학습 데이터 X : {X_train.shape}, 학습 데이터 y : {y_train.shape}")
print(f"테스트 데이터 X : {X_test.shape}, 테스트 데이터 y : {y_test.shape}")
# Out:
# 학습 데이터 X : (120, 4), 학습 데이터 y : (120,)
# 테스트 데이터 X : (30, 4), 테스트 데이터 y : (30,)

# %% [markdown]
# ### 연습문제01-3. DecisionTreeClassifier를 사용하여 모델을 생성하세요.
# - 학습 데이터를 사용하여 모델을 학습시키세요.
# - 학습 완료 후, 학습 데이터에 대한 정확도를 출력하세요

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train,y_train)
print(f"학습 데이터 정확도 : {dt.score(X_train,y_train)}")
# Out:
# 학습 데이터 정확도 : 1.0

# %% [markdown]
# ### 연습문제04. 학습된 모델을 사용하여 테스트 데이터를 예측하세요.
# - 테스트 데이터에 대한 정확도를 출력하세요.
# - classification_report를 사용하여 평가 결과를 상세히 출력하세요.

# %%
from sklearn.metrics import classification_report
print(f"테스트 데이터 정확도 : {dt.score(X_test,y_test)}")
new_y = dt.predict(X_test)
print(classification_report(y_test,new_y))
# Out:
# 테스트 데이터 정확도 : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ### 연습문제05. 학습된 결정 트리를 시각화하세요.
# - plot_tree 함수를 사용하여 결정 트리의 구조를 그리세요.
# - 트리 시각화를 통해 어떤 특성이 중요한지 설명하세요.

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(14,8))
plot_tree(dt,class_names=data.target_names,feature_names=data.feature_names,filled=True)
plt.show()
dt.feature_importances_
plt.barh(data.feature_names, dt.feature_importances_)
# Out:
# <BarContainer object of 4 artists>
